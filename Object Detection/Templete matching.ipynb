# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
full = cv2.imread('../Reference/DATA/sammy.jpg')
full = cv2.cvtColor(full,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(full)

# %%
face = cv2.imread('../Reference/DATA/sammy_face.jpg')
face = cv2.cvtColor(face,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(face)

# %%
face.shape
# Out:
# (375, 486, 3)

# %%
full.shape
# Out:
# (1367, 1025, 3)

# %% [markdown]
# #### Using Template matching technique we are matching smaller image or face in the larger image which is present exactly same. It keeps scanning the full image pixel by pixel until it matches with the face image

# %%
eval('1+1')
# Out:
# 2

# %%
func = 'sum'
eval(func)
# Out:
# <function sum(iterable, /, start=0)>

# %%
# ALl 6 methods for comparison in a list
# The functions are in string which can be converted into function using eval 
methods = ['cv2.TM_CCOEFF','cv2.TM_CCOEFF_NORMED','cv2.TM_CCORR','cv2.TM_CCORR_NORMED','cv2.TM_SQDIFF','cv2.TM_SQDIFF_NORMED']

# %%
for m in methods:
    
    # CREATE A COPY
    full_copy = full
    
    # USE THE METHOD
    method = eval(m)
    res = cv2.matchTemplate(full_copy,face,method)
    
    min_val,max_val,min_loc,max_loc = cv2.minMaxLoc(res)
    
    if method in [cv2.TM_SQDIFF,cv2.TM_SQDIFF_NORMED]:
        top_left = min_loc
    else:
        top_left = max_loc
        
    height,width,channel = face.shape
    
    bottom_right = (top_left[0]+width,top_left[1]+height)
    
    cv2.rectangle(full_copy,top_left,bottom_right,(255,0,0),10)
    
    # PLOT AND SHOW IMAGES
    
    plt.subplot(121)
    plt.imshow(res)
    plt.title("HEATMAP")
    
    plt.subplot(122)
    plt.imshow(full_copy)
    plt.title("DETECTION OF TEMPLATE")
    
    # TITLE WITH THE TEMPLATE USED
    plt.suptitle(m)
    
    plt.show()
    
    print('\n\n')
