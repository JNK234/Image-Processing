# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading Image as COLOR Image

# %%
img = cv2.imread('../Reference/DATA/rainbow.jpg')

# %%
plt.imshow(img)

# %% [markdown]
# ### Reading Image as Gray Scale Image

# %%
img = cv2.imread('../Reference/DATA/rainbow.jpg',0)
plt.imshow(img,cmap = 'gray')

# %%
int(255/2)
# Out:
# 127

# %%
img.max()
# Out:
# 214

# %%
int(214/2)
# Out:
# 107

# %%
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# %%
ret
# Out:
# 127.0

# %%
plt.imshow(thresh1,cmap='gray')

# %% [markdown]
# Basically Binary threshold Means any pixel value below 127 is considered as 0 and above 127 is considered as 255.
# Thresh Binaty Inv works the opossite way

# %%
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)

# %%
plt.imshow(thresh1,cmap='gray')

# %% [markdown]
# For Thresh Trunc some pixel values which is more than 127 is bought back to 127 and others are left as it is

# %%
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)

plt.imshow(thresh1,cmap='gray')

# %% [markdown]
#  For Thresh Tozero some pixel values which is more than 127 is kept the same and others are 0

# %%
img = cv2.imread('../Reference/DATA/crossword.jpg',0)
plt.imshow(img,cmap='gray')

# %%
def show_pic(img):
    fig = plt.figure(figsize=(17,17))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap='gray')

# %%
show_pic(img)

# %%
img.max()
# Out:
# 255

# %%
ret,thresh1 = cv2.threshold(img,160,255,cv2.THRESH_BINARY)
show_pic(thresh1)

# %%
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,8)
show_pic(th2)

# %%
blended = cv2.addWeighted(src1=thresh1,alpha = 0.6,src2=th2,beta=0.4,gamma=0)
show_pic(blended)
