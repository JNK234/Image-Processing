# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

# %%
os.listdir("..")
# Out:
# ['.DS_Store', 'Numpy ', 'OpenCV', '.ipynb_checkpoints', '.git', 'Reference']

# %%
img = cv2.imread('../Reference/DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %% [markdown]
# ### MATPLOTLIB -> RED-GREEN-BLUE
# ### OPENCV -> BLUE->GREEN->RED

# %% [markdown]
# Convert the color format

# %%
fixed_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fixed_image)

# %% [markdown]
# To read in greyscale

# %%
img_gray = cv2.imread("../Reference/DATA/00-puppy.jpg",cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
img_gray.min()
# Out:
# 1

# %%
img_gray.max()
# Out:
# 209

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %% [markdown]
# ### Resize Image

# %%
plt.imshow(fixed_image)

# %%
 fixed_image.shape
# Out:
# (1300, 1950, 3)

# %%
new_img = cv2.resize(fixed_image,(1000,400))

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (400, 1000, 3)

# %%
w_ratio = 0.5 # 50% of original
h_ratio = 0.2 # 20% of original

# %%
new_image =  cv2.resize(fixed_image,(0,0),fixed_image,w_ratio,h_ratio)

# %%
plt.imshow(new_image)

# %%
 new_image.shape
# Out:
# (260, 975, 3)

# %%
new_img = cv2.flip(fixed_image,0)

# %%
plt.imshow(new_img)

# %%
new_img = cv2.flip(fixed_image,1)
plt.imshow(new_img)

# %%
type(new_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite("new_image.jpeg",fixed_image)
# Out:
# True

# %%
os.listdir()
# Out:
# ['Untitled.ipynb', 'new_image.jpeg', '.ipynb_checkpoints']

# %%
fig = plt.figure(figsize=(20,16))
ax = fig.add_subplot(111)
ax.imshow(fixed_image)
